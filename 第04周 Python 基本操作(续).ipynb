# %% [markdown]
# <table border="0" width="100%"><tr><td width=80 bgcolor="white"><p align="left"><img src="./Images/book.png" align="left" height="20"></p></td><td align="center" bgcolor="white"><font size="7">第2章 Python 基本操作（续）</font></td></tr></table>
#
# <hr style="border:none;border-top:1px dotted red;">

# %% [markdown]
# # <font color=#A93226>【线上学习内容】</font>

# %% [markdown]
# ## 2.5　布尔类型、逻辑运算与关系运算
#
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642683" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# ## 2.6　常用内置函数
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642683" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# ## 学习目标
# • 掌握变量基本概念<br>
# • 熟悉表达式基本操作<br>
# • 掌握整数类型基本概念和操作<br>
# • 掌握浮点数类型基本概念和操作<br>
# • 掌握字符串类型基本概念和操作<br>
# • 掌握布尔类型基本概念和操作<br>
# • 掌握输入输出函数的基本用法<br>
# • 了解常用内置函数<br>
# • 掌握导入模块的方法<br>

# %% [markdown]
# ### 2.4.6　字符串其他常用方法

# %% [markdown]
# #### (1) 字符串的in 和not in 操作符 <br>
# ``in`` 和``not in`` 操作符也可以用于字符串。用``in`` 或``not in`` 连接两个字符串得到的表达式，将求值为布尔值True 或False。用于测试第一个字符串（精确匹配，区分大小写）是否在第二个字符串中。

# %%
a = 'Hello' in 'Hello World'
a + 1
# Out:
# 2

# %%
'hello' in 'Hello World'
# Out:
# False

# %% [markdown]
# #### (2) 字符串方法upper()、lower()、isupper()和islower() <br>
# ``upper()``和``lower()``字符串方法返回一个新字符串，其中原字符串的<font color=red>所有字母</font>都被相应地转换为大写或小写。字符串中非字母字符保持不变。

# %%
sayHello = 'Hello world!'
print(sayHello.upper())
print(sayHello)   # 这些方法没有改变字符串本身，而是返回一个新字符串

# %%
sayHello = sayHello.lower()
print(sayHello)

# %% [markdown]
# 如果需要进行大小写无关的比较，``upper()``和``lower()``方法就很有用。例如，对于用户输入的名字，忽略大小写：

# %%
userName = input('请输入用户名：')
userName.lower() == 'xzl'

# %% [markdown]
# 如果字符串至少有一个字母，并且所有字母都是大写或小写，``isupper()``和``islower()``方法就会相应地返回布尔值True。否则，该方法返回False。

# %%
'Hello world!'.isupper()

# %%
'Hello world!'.islower()

# %%
'Hello world!'.upper().isupper()

# %%
'Hello world!'.upper().lower().isupper()  # 这样做的表达式看起来就像方法调用链。

# %% [markdown]
# #### (3) isX 字符串方法 <br>
# 下面是一些常用的isX 字符串方法：
# * ``isalpha()``返回True，如果字符串只包含字母，并且非空；
# * ``isalnum()``返回True，如果字符串只包含字母和数字，并且非空；
# * ``isdecimal()``返回True，如果字符串只包含数字字符，并且非空；
# * ``isspace()``返回True，如果字符串只包含空格、制表符和换行，并且非空；
# * ``istitle()``返回True，如果字符串仅包含以大写字母开头、后面都是小写字母的单词。

# %%
'hello'.isalpha()

# %%
'你好'.isalpha()

# %%
'hello123'.isalpha()

# %%
'hello123'.isalnum()

# %%
'123'.isdecimal()

# %%
't'.isspace()

# %%
' \t'.isspace()

# %%
'This Is A Test.'.istitle()

# %% [markdown]
# 这些函数在验证用户输入时，非常有用。例如，当需要用户输入年龄时，可以使用``isdecimal()``判断用户的输入是否只包含数字。

# %%
age = input()
age.isdecimal()

# %% [markdown]
# #### (4) 字符串方法startswith()和endswith() <br>
# ``startswith()``和``endswith()``方法返回True，如果它们所调用的字符串以该方法传入的字符串开始或结束。否则，方法返回False。这在判断字符串是否是正确URL或者正确的文件后缀时，非常有用：

# %%
'http://www.swufe.edu.cn'.startswith('http')

# %%
'file1.py'.endswith('.xlsx')

# %% [markdown]
# #### (5) 字符串方法join()和split() <br>
# 如果有一个字符串列表，需要将它们连接起来，成为一个单独的字符串，``join()``方法就很有用。``join()``方法在一个字符串上调用，参数是一个字符串列表，返回一个字符串。返回的字符串由传入的列表中每个字符串连接而成:

# %%
','.join(['管理部', '人事部', '销售部'])

# %% [markdown]
# ``split()``方法做的事情正好相反：它针对一个字符串调用，返回一个字符串列表。

# %%
'管理部,人事部,销售部'.split(',')

# %%
'管 理 部     人 事 部     销 售 部'.split()

# %% [markdown]
# 这在对文件内容分行操作时，非常有用：

# %%
swufeIntroduction = '''西南财经大学是教育部直属的国家“211工程”和“985工程”优势学科创新平台建设的全国重点大学，也是国家“双一流”建设高校。
学校地处国家历史文化名城、南方丝绸之路的起点、素有“天府之国”美誉的成都，有光华、柳林两校区，总占地2300余亩。光华铁树穿越年轮时光感受历史缅怀先贤,巍巍钟楼傲然屹立感受青春与未来对话,这里古今融通、传统与现代交相辉映，实乃读书治学的理想园地。
学校始于1925年在上海创立的光华大学。1938年，因抗战西迁建立光华大学成都分部；1952-1953年汇聚西南地区17所院校的财经系科组建四川财经学院,这是建国初期国家按大区布局的四所本科财经院校之一，也是西南地区唯一的综合性高等财经学府;1960年后历经分设、合并、更名等，于1978年恢复为四川财经学院；1979年由四川省划归中国人民银行主管，逐渐形成了学校独特的金融行业背景和出色的金融学科优势；1985年更名为西南财经大学，1997年成为国家“211工程”重点建设高校，2000年以独立建制划转教育部管理，2011年成为国家“985工程”优势学科创新平台建设高校。90余年的办学历史形成了自己独特的办学特色、文化传统、精神内涵和社会声誉。
黄浦浣花风雨长，光华柳林谱华章。学校始终与国家民族共命运，格致诚正，兴学报国；始终与时代发展同进步，经世济民，励精图强，在国家经济腾飞中写下了隽永篇章。
'''
print(swufeIntroduction)

# %%
swufeIntroduction.split('\n')

# %%
swufeIntroduction.split('\n')[2] #从结果猜猜，这是做什么？

# %% [markdown]
# <font color=#A93226><b>【课堂练习】</b></font>
#
# <font size=3 face="楷体-简">已知字符串“``1031473,2282,农夫山泉矿泉水550ml,1.88,20,5``”表示的是一条销售记录，其结构为：订单号,商品ID,商品名称,单价,购买数量,退货数量。
#
# 请编写程序计算出这条销售记录的销售金额。</font>

# %%
sale_info = '1031473,2282,农夫山泉矿泉水550ml,1.88,20,5'
sale_info_splited = sale_info.split(',')
sale_amt = float(sale_info_splited[3])*(int(sale_info_splited[-2]) - int(sale_info_splited[-1]))
sale_amt

# %% [markdown]
# #### (6) 用rjust()、ljust()和center()方法对齐文本 <br>
# ``rjust()``和``ljust()``字符串方法返回调用它们的字符串的填充版本，通过插入空格来对齐文本。这两个方法的第一个参数是一个整数长度，用于对齐字符串：

# %%
'Hello'.rjust(20)

# %% [markdown]
# ``rjust()``和``ljust()``方法的第二个可选参数将指定一个填充字符，取代空格字符:

# %%
'Hello'.ljust(20, '-')

# %% [markdown]
# ``center()``字符串方法与``ljust()``与``rjust()``类似，但它让文本居中，而不是左对齐或右对齐。

# %%
'Hello'.center(20, '=')

# %%
leftWidth = 20
rightWidth = 6
print("Items".center(leftWidth + rightWidth, '-'))
chapter1 = "sandwiches"
chapter2 = "apples"
chapter3 = "cookies"
chp1Page = 30
chp2Page = 330
chp3Page =6100
print(chapter1.ljust(leftWidth, '.') + str(chp1Page).rjust(rightWidth))
print(chapter2.ljust(leftWidth, '.') + str(chp2Page).rjust(rightWidth))
print(chapter3.ljust(leftWidth, '.') + str(chp3Page).rjust(rightWidth))

# %% [markdown]
# #### (7) 用strip()、rstrip()和lstrip()删除空白字符 <br>
# 有时候你希望删除字符串左边、右边或两边的空白字符（空格、制表符和换行符）。
# * ``strip()``字符串方法将返回一个新的字符串，它的开头或末尾都没有空白字符。
# * ``lstrip()``方法将相应删除左边的空白字符。
# * ``rstrip()``方法将相应删除右边的空白字符。

# %%
sayHello = ' Hello World '
print('-' + sayHello.strip() + '-')
print('-' + sayHello.lstrip() + '-')
print('-' + sayHello.rstrip() + '-')
print('-' + sayHello + '-')

# %% [markdown]
# 有一个可选的字符串参数，指定两边的哪些字符应该删除。

# %%
tmpStr = 'abcbac西南财经大学bcdabc'
tmpStr.strip('acb') #向strip()方法传入参数'acb'，告诉它在变量中存储的字符串两端，
                    #删除出现的a、c和b。传入strip()方法的字符串中，
                    #字符的顺序并不重要：strip('acb')做的事情和
                    #strip('abc')或strip('cba')一样。

# %% [markdown]
# #### (8) 用replace()替换字符串
# 如果希望替换字符串中的某些子串，可以使用``replace()``方法。

# %% [markdown]
# <font color=#A93226><b>【例 2-17】</b></font> <font size=3 face="楷体-简">利用 replace 函数， 将字符串“ fintech 是金融科技。”中的“ f”替换成 “F”，将“t”替换成“T”。</font>

# %%
'fintech是金融科技。'.replace('f','F').replace('t','T')

# %% [markdown]
# #### (9) 函数ord()和chr()的使用
# `ord()`函数以一个字符（长度为1的字符串）作为参数，返回对应的 ASCII 数值，或者 Unicode 数值，如果所给的 Unicode 字符超出了你的 Python 定义范围，则会引发一个 TypeError 的异常，语法如下：
# ```python
#    ord(c)
# ```
# 其中参数c为字符，返回值是对应的十进制整数。

# %%
ord('a')

# %%
ord('中')

# %% [markdown]
# `chr()`函数则与`ord()`函数相反，以一个整数作为参数，返回该整数对应的字符，语法如下：
# ```python
#    chr(i)
# ```
# 其中参数i可以是10进制也可以是16进制的形式的数字，返回值是当前整数对应的字符。

# %%
chr(65)

# %%
chr(22269)

# %% [markdown]
# ### <a href="https://doubao.com/bot/FWheXcyv" style="color:green;">问问大模型</a>
# ---
# <font style="color:gray;">复制下面的提示词，点击"问问大模型"，将提示词粘贴到你所使用的大模型</font>
#
#
#
# <font style="color:brown;font-weight: bold;">提示词:</font><br>
#
# ```markdown
# 我有以下销售数据，请你用Python帮我统计销售金额，请注意，我是一个Python初学者，只学习了变量、表达式、整数、浮点数和字符串，对于列表有简单的了解。
# “
# 订单号,商品ID,商品名称,单价,购买数量,退货数量
# 1108258,9255,香飘飘Meco牛乳茶300ml,8.00,2,0
# 1108259,5603,南孚丰蓝1号电池1对,9.00,1,0
# 1108276,5858,有友酸菜泡凤爪泡鸡爪120g,6.80,1,0
# 1108300,5069,重庆小天鹅火锅底料150g,4.50,1,0
# 1108402,2097,喜之郎葡萄&苹果果肉果冻200g,2.80,1,0
# 1108557,2610,老干妈辣三丁油辣椒280g,10.00,1,0
# 1108557,2108,伊利谷粒多红豆红米花生牛奶250ml,2.50,1,0”
# ```
# ---
#
# <img src='./Images/4_1.png' style="height: 1000px; border: 0.1px solid black;">

# %% [markdown]
# ### 2.4.7　打印输出 print 函数
#
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642679" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>
#
# ``print()``函数的作用是将输入的参数打印出来，默认打印到屏幕上，其语法格式如下：
# ```python
# print(<逗号分隔的需打印参数列表>)
# ```

# %% [markdown]
# <font color=#A93226><b>【例 2-18】</b></font> <font size=3 face="楷体-简">输出股票的代码、名称、开盘价、收盘价及收盘开盘价差。</font>

# %%
openPrice, closePrice = 35.2, 36.8
print(600000,'浦发银行', openPrice, closePrice, closePrice - openPrice)

# %%
help(print)

# %%
print("Hello！")
print("西南财经大学")

# %% [markdown]
# 如果打印后不想换行，可以使用下面的方法：

# %%
print("Hello！", end="")
print("西南财经大学", end="_")

# %% [markdown]
# 所以，end是什么作用？

# %% [markdown]
# ### 2.4.8　获取用户输入 input 函数
# ``input()``函数等待用户在键盘上输入一些文本，并按下回车键。这个函数的值为一个<font color=red>字符串</font>，即用户输入的文本。

# %%
myInputVal = input()  #输入一个数字

# %%
myInputVal + 10  #出错了，为什么？怎么办？

# %% [markdown]
# <font color=#A93226><b>【例 2-19】</b></font> <font size=3 face="楷体-简">用户分别输入商品的价格和购买数量，计算需要支付的金额。</font>

# %%
price = float(input("请输入商品价格:"))
quantity = int(input("请输入购买数量:"))
price * quantity

# %% [markdown]
# ## 2.4.9 <font color=#A93226>案例：</font>等额本息还款法每月还款额的计算
#
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642681" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>
#
# <font size=3 face="楷体-简">等额本息还款法（等额法）， 即把按揭贷款的本金总额与利息总额相加， 平均分摊到 还款期限的每个月当中，每个月还款额是固定的，这样每个月还款额中的本金比重逐月递 增，利息比重逐月递减。
#
# 依据等额本息还款法的规则，可以推导出以下公式：
# $$ result = \frac{total * rate\_month * (1 + rate\_month)^{terms}}{(1 + rate\_month)^{terms} –1}$$
#
# 其中， result 为每月还款额， total 为贷款总额， rate_month 为银行月利率， terms 为 贷款总期数（按月算）。
#
# 编写程序，根据用户输入的贷款额度和年限，计算其利用等额本息还款法时每月的还款额。
# </font>

# %%
total = float(input("请输入贷款金额（元）："))
terms = int(input("请输入贷款期限（月）："))
rateYear = 0.049    #年利率为4.9%
rateMonth = rateYear / 12   #计算月利率
result = (total * rateMonth * (1 + rateMonth) ** terms) \
            / ((1 + rateMonth) ** terms - 1)
print("每月应还：",result)

# %% [markdown]
# ## 2.5　布尔类型、逻辑运算与关系运算
#
# <a href="https://www.xuetangx.com/learn/swufe08091006588/swufe08091006588/26288051/video/66581737" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# <table bgcolor=#FFFAFA width=100%><tr><td>
#
# <font size=3 color=#1E90FF><b>【课堂提问】</b>
#
# <font size=3 face="楷体-简"  color=#1E90FF>1. True 和 False 是Python中的什么类型的实例？<br><br>
# 2. 逻辑运算and和or的运算规则是什么？<br><br>
# 3. 下列表达式的结果分别是什么？
# </font>
# </font>
# </td></tr></table>
#
# ```python
#     True or False
#     True and False
#     True + False
# ```

# %% [markdown]
# ### 2.5.1　布尔类型
# Python 中的布尔类型只有两种值：True 和 False。

# %%
1 = 2

# %%
1 == 2

# %%
1 == 1

# %% [markdown]
# 注意：在Python中=用于赋值，==用于判断是否相等。

# %%
hi = "Hello"  
hi == "hello"

# %%
True = 1 + 1

# %%
true = 1 + 1 #虽然没有错，但是不建议用这样的变量名
true

# %% [markdown]
# ### 2.5.2　逻辑运算
# Python中3个布尔操作符（and、or 和not）用于计算布尔值。像比较操作符一样，它们将这些表达式求值为一个布尔值。
#
# and和or操作符总是接受两个布尔值（或表达式），所以它们被认为是“**二元**”操作符。
#
# **and**: 如果两个布尔值都为True，and操作符就将表达式求值为True，否则求值为False。

# %%
True and True

# %%
True and False

# %%
(1 == 1) and (10 > 100)

# %% [markdown]
# **or**: 只要有一个布尔值为真，or 操作符就将表达式求值为True。如果都是False，所求值为False。

# %%
False or True

# %%
False or False

# %%
(1 == 1) or (10 > 100)

# %% [markdown]
# **not**: 和and 和or 不同，not 操作符只作用于一个布尔值（或表达式）。not 操作符求值为相反的布尔值。

# %%
not True

# %%
not not not not False

# %% [markdown]
# ### 2.5.3　关系运算
# 布尔类型值通常来自于关系运算的结果。

# %% [markdown]
# <font color=#A93226><b>【例 2-20】</b></font> <font size=3 face="楷体-简">股价波动率为 0.25， 判断其是否符合投资者股价波动率低于 20% 的限制条件。</font>
#
# Python 代码如下所示：

# %%
volatility = 0.25
volatility < 0.2

# %% [markdown]
# Python中包含各种关系比较的操作符：
#
# |运算符|举例|结果|功能说明|
# |:---:|:---|:---|---|
# |<|10 < 8|False|小于|
# |>|10 > 8|True|大于|
# |<=|10 <= 8|False|小于等于||
# |>=|10 >=10|True|大于等于|
# |==|10 == 8|False|等于|
# |!=|10 != 8|True|不等于|

# %% [markdown]
# Python表达式支持多个比较运算。这种表达式和数学中的表达方式非常接近。

# %% [markdown]
# <font color=#A93226><b>【例 2-21】</b></font> <font size=3 face="楷体-简">两个数的平均数总是在这两个数的较小数和较大数之间。</font>
#
# Python 代码如下所示：

# %%
x = 10
y = 8
min(x, y) <= (x + y) / 2 <= max(x, y)

# %% [markdown]
# 字符串也可以比较大小，两个字符串的大小比较规则是：从第一个字符开始，如果第一个字符相同则顺次向后比较，直到出现不同的字符为止，以第一个不同字符的Unicode值确定大小：

# %%
"abcd" < "abdd"

# %% [markdown]
# #### Python 表达式中操作符优先级（从上往下，优先级越来越低）：
#
# |运算符|功能说明|
# |:---|:--|
# |**|指数|
# |\*、/、//、%|乘法、除法、整除、取余数|
# |+、-|加法、减法|
# |in、not in、<、<=、>、>=、!=、==|成员测试、大小比较|
# |not|逻辑非|
# |and|逻辑与|
# |or|逻辑或|
#
# 一般来说都会用**括号**来改变通常的优先级。

# %% [markdown]
# ## 2.6　常用内置函数
# <a href="https://www.xuetangx.com/learn/swufe08091006588/swufe08091006588/26288051/video/66581737" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# <table bgcolor=#FFFAFA width=100%><tr><td>
#
# <font size=3 color=#1E90FF><b>【课堂提问】</b>
#
# <font size=3 face="楷体-简"  color=#1E90FF>1. 下列程序的运行结果分别是什么？<br><br>
# </font>
# </font>
# </td></tr></table>
#
# ```python
#     len("西南\n财经\t大学")
#     max(1,2,'3')
# ```

# %% [markdown]
# Python中共有75个内置函数，这些是Python自带的函数，在需要使用时可以直接调用。下表列出了在处理财经数据时常用的Python内置函数：
#
# |函数名称|代码示例|结果|功能描述|
# |:---|:---|:---|:---|
# |abs|x = -10<br>abs(x)|10|求绝对值|
# |float|float('10.8')|10.8|将整数或者字符串转换为浮点数|
# |int|int(10.8)|10|将浮点数截断小数部分后转换为整数或者将只包含数字的字符串转换化为整数|
# |len|len('金融科技')|4|获得字符串、列表、元组、集合或字典的长度（即元素个数）|
# |max|max(10,-10.8,3,58,20.5)|58|获得一组数据中最大值|
# |min|min(10,-10.8,3,58,20.5)|-10.8|获得一组数据中最小值|
# |range|list(range(0,6,2))|[0,2,4]|产生一个可迭代对象，在此列中从0开始到6之前（即不包括6），以步长为2产生可迭代对象后利用list函数转换成列表|
# |sum|sum([10,3,-10.8,58])|60.2|获得一组数据的和，在此列中获得列表[10,3, -10.8,58]中的数据之和|

# %%
help(max)

# %%
max(10,-10.8,3,58,20.5)

# %%
help(min)

# %%
min(10,-10.8,3,58,20.5)

# %%
help(sum)

# %%
sum([10,3,-10.8,58])

# %% [markdown]
# ### <a href="https://doubao.com/bot/FWheXcyv" style="color:green;">问问大模型</a>
# ---
# <font style="color:gray;">复制下面的提示词，点击"问问大模型"，将提示词粘贴到你所使用的大模型</font>
#
#
#
# <font style="color:brown;font-weight: bold;">提示词:</font><br>
# 我是Python初学者，请你对Python内置函数中的max、range、sum举几个例子，并详细说明它们的语法。
#
# ---

# %% [markdown]
# <div style="background-color: #fffaf0; border-left: 5px solid #f6ad55; padding: 20px; border-radius: 8px; font-family: sans-serif; margin: 20px 0;">
#     <h2 style="color: #dd6b20; margin-top: 0;">🔄 AI 输出解析 (Output Parsing)：打通大模型与金融计算的桥梁</h2>
#     <p style="font-size: 16px; color: #333; line-height: 1.6;">你可能会觉得 <code>int()</code> 和 <code>float()</code> 的转换很繁琐。但在构建 <b>AI 财务助手</b>时，数据类型转换是你必须掌握的“核心魔法”。</p>
#     <table style="width: 100%; border-collapse: separate; border-spacing: 10px; border: none; background: none;">
#         <tr style="background: none; border: none;">
#             <td style="width: 50%; background: white; padding: 15px; border-radius: 10px; box-shadow: 0 2px 5px rgba(0,0,0,0.05); vertical-align: top; border: none; border-top: 3px solid #cbd5e0;">
#                 <h4 style="color: #4a5568; margin-top: 0;">大模型（LLM）的局限</h4>
#                 <p style="font-size: 14px; color: #666; margin-bottom: 0;">像 ChatGPT 这样的大语言模型，无论它多么聪明，它的世界里只有<b>文本（String）</b>。如果你让它提取财报数据，它可能会回答：<br><br><i>“该公司的营收增长率为 15.5%。”</i></p>
#             </td>
#             <td style="width: 50%; background: white; padding: 15px; border-radius: 10px; box-shadow: 0 2px 5px rgba(0,0,0,0.05); vertical-align: top; border: none; border-top: 3px solid #ed8936;">
#                 <h4 style="color: #dd6b20; margin-top: 0;">Python 的接管与转换</h4>
#                 <p style="font-size: 14px; color: #666; margin-bottom: 0;">Python 程序无法直接用一段文字做数学运算。我们需要截取其中的 <code>'15.5'</code>，并使用 <code>float('15.5')</code> 将其转换为浮点数。这在 AI 工程中被称为<b>输出解析（Output Parsing）</b>。</p>
#             </td>
#         </tr>
#     </table>
#     <h3 style="color: #2c3e50; margin-top: 20px;">💡 Vibe Coding 启示录</h3>
#     <p style="font-size: 15px; color: #444; line-height: 1.6;">在未来，当你用自然语言指挥 AI 写代码时，如果程序报错 <code>TypeError</code>（类型错误），你就能立刻反应过来：“哦！AI 把数字当成字符串处理了！”掌握类型转换，你就能在 AI 生成的代码基础上进行精准的微调。</p>
# </div>

# %% [markdown]
# ## 2.7 导入模块
# 在利用Python处理财经数据时，除了加减乘除等基本算术运算外，还会涉及到更加复杂的处理、运算和统计分析功能，这时可以使用Python的扩展工具：**模块**。
#
# 模块是第三方专门为了解决某些特定问题而编写的工具。Python本身自带了一些常用的模块，例如，math模块中具有较为复杂的求解正弦、余弦和平方根等运算，这些模块不需要安装，但是在使用前需要导入。
#
# 导入模块使用**import**关键字，Python中导入模块有不同的方法：

# %% [markdown]
# ### （1）利用``import 模块名``
# 导入整个模块：

# %%
import math
math.sqrt(4)

# %% [markdown]
# ### （2）利用``import模块名 as 名称缩写``
# 导入整个模块的同时给该模块取个较短的别名：

# %%
import numpy as np
np.sqrt(4)

# %% [markdown]
# ### （3） 利用``import模块名.子模块名 as 名称缩写``
# 导入某个模块子模块的同时给该子模块取个较短的别名：

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### （4）利用``from 模块名 import 函数``
# 导入模块中指定函数：

# %%
from math import sqrt, exp
sqrt(4)

# %% [markdown]
# ### （5）利用``from 模块名.子模块名 import 函数``
# 导入某个模块的子模块中指定函数：

# %%
from matplotlib.pyplot import plot

# %% [markdown]
# Windows 下安装非标准库，需要在命令提示符中输入：
# ```python
# pip install 库名
# ```
# Linux 和 Mac OS X 中则是在终端输入上述命令。

# %% [markdown]
# <div style="background-color: #f3e8ff; border-left: 5px solid #9f7aea; padding: 20px; border-radius: 8px; font-family: sans-serif; margin: 20px 0;">
#     <h2 style="color: #6b46c1; margin-top: 0;">🧰 外部库 (Libraries) = AI 智能体的“神兵利器”</h2>
#     <p style="font-size: 16px; color: #333; line-height: 1.6;">刚才我们通过 <code>import math</code> 计算了4 的平方根。但在 AI 时代，我们引入外部库，不仅仅是为了自己调用，更是为了<b>给大模型配备工具 (Tool Calling)</b>。</p>
#     <div style="background: white; padding: 15px; border-radius: 10px; box-shadow: 0 2px 5px rgba(0,0,0,0.05); margin-top: 15px;">
#         <h4 style="color: #2d3748; margin-top: 0; border-bottom: 1px dashed #ccc; padding-bottom: 10px;">🤖 为什么 AI 需要 Python 库？</h4>
#         <ul style="font-size: 14px; color: #555; line-height: 1.8;">
#             <li><b>AI 会算错数：</b> 大语言模型是靠“预测下一个词”来工作的，它们经常会在复杂的数学公式（如复利计算、期权定价、距离公式）上胡说八道（产生幻觉）。</li>
#             <li><b>工具调用 (Tool Calling)：</b> 聪明的开发者不再让 AI 自己硬算。我们会向 AI 提供 <code>math</code> 库或自定义的函数。当 AI 遇到数学题时，它会自动生成调用 <code>math.sin()</code> 的 Python 代码，让计算机得出 100% 准确的结果，再把结果返回给你。</li>
#         </ul>
#     </div>
#     <div style="background: #e9d8fd; border-radius: 5px; padding: 15px; margin: 15px 0; color: #555; font-style: italic;">
#         <strong>Vibe Coding 实践：不要死记硬背！</strong><br>
#         Python 有成千上万个外部库。在氛围编程中，你<b>完全不需要背诵</b>每个库里有哪些函数。你只需要用大白话告诉 AI：<i>“请帮我引入合适的 Python 库，计算成都市到北京市的球面距离。”</i> AI 会自动替你 <code>import math</code> 并写出哈弗辛公式。你只需看懂逻辑即可！
#     </div>
# </div>

# %% [markdown]
# ## 2.8 综合案例：我国人口增长率变化分析
#
# <a href="https://www.xuetangx.com/learn/swufe08091006588/swufe08091006588/26288051/video/66581738" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>
#
# 我国人口数量一直保持世界人口较大比例。1850年我国人口数量约4.3亿，占世界人口的34%。1949年，我国大陆人口为5.4167亿，占世界人口比例为22%。由于人口结构的原因，我国人口总量仍在持续增长，下表是我国自1949年至2019年每年年末人口数：
#
# <img src='./Images/4_2.png' width=500  style='display: block; margin: 0 auto;'><br>
#
#
# 根据上表，可画出如图2-3所示的1949年至2019年期间每隔10年的人口柱状图:

# %%
# 这段代码暂时不能理解没有关系，继续往后面学习
import matplotlib.pyplot as plt
# %matplotlib inline
years = [1949, 1959, 1969, 1979, 1989, 1999,2009, 2019]
population = [54167, 67207, 80671, 97542, 112704, 125786, 133450, 140005]
plt.bar(years, population , tick_label=years);

# %% [markdown]
# 基于上述结果，计算自1949年至2019年期间以10年为间隔的人口增长率：

# %%
rate1 = (67207 - 54167) / 54167
rate2 = (80671 - 67207) / 67207
rate3 = (97542 - 80671) / 80671
rate4 = (112704 - 97542) / 97542
rate5 = (125786 - 112704) / 112704
rate6 = (133450 - 125786) / 125786
rate7 = (140005 - 133450) / 133450
years_growth_rate = [1959,1969,1979,1989,1999,2009,2019]
pop_growth_rate = [rate1,rate2,rate3,rate4,rate5,rate6,rate7]
plt.xticks(years_growth_rate)
plt.plot(years_growth_rate, pop_growth_rate);

# %% [markdown]
# <font color=#A93226><b>【课堂案例】</b></font>  <font size=3 face="楷体-简">
#
# 读取Data/Sales目录下的销售数据文件，并打印出退货数量大于0的销售记录的销售总额。</font><br><br>
#
# <font size=1 color="gray">
# 注：在这个案例中，将提前了解一些关于列表、循环和文件的内容，不能掌握也没有关系，后面章节会详细讲解。</font>

# %%
import os
#获取目录下的文件名列表
fileNameList = [item for item in os.listdir('Data/Sales/') if item.endswith('.csv') and not item.startswith('.')]
saleAmt = 0
for fileName in fileNameList:  #循环处理每一个文件
    saleFile = open('Data/Sales/' + fileName, encoding='utf8')
    saleFile.readline()  #读取文件的第一行，即标题行
    for line in saleFile:  #从文件的第二行，即数据行开始处理每一行
        detail = line.replace('"', '').strip('\n').split(',')
        if int(detail[5])>0:  #只统计退货数量大于0的销售记录
            saleAmt = saleAmt + (int(detail[4]) - int(detail[5])) * float(detail[3]) 
print('销售总额为：{:.2f}元'.format(saleAmt))

# %% [markdown]
# <font color=#A93226><b>【课堂练习】</b></font>  <font size=3 face="楷体-简">
#
# 读取Data/Sales目录下的销售数据文件，并打印出所有商品的平均价格。</font>

# %%
import os
fileNameList = [item for item in os.listdir('Data/Sales/') if item.endswith('.csv') and item.startswith('2020')]
price_sum = 0
qty = 0
for fileName in fileNameList:  
    saleFile = open('Data/Sales/' + fileName, encoding='utf8')
    saleFile.readline()  
    for line in saleFile:  
        detail = line.replace('"', '').strip('\n').split(',')
        price_sum += float(detail[3])
        qty += 1
                           
print('所有商品的平均价格为：{:.2f}元'.format(price_sum/qty))

# %% [markdown]
# ## 【引导案例解析】
# 根据对引导案例的分析，首先需要输入姓名、日常生活支出、学习用品支出和其他方面支出等基本信息；接着计算出该月总支出；最后打印出各类支出的占比详情。
#
# 程序代码如下：

# %%
stu_name = input('请输入姓名：')
living_expenses = float(input('请输入日常生活支出（元）：'))
school_things = float(input('请输入学习用品支出（元）：'))
other_expendses = float(input('其他方面支出（元）：'))
total_expenses = living_expenses + school_things + other_expendses
print('=' * 35)
print('以下是{}的支出情况：'.format(stu_name))
print('日常生活支出：{0:.2f}元，占比：{1:.2%}'.format(living_expenses, 
                                          living_expenses / total_expenses))
print('学习用品支出：{0:.2f}元，占比：{1:.2%}'.format(school_things, 
                                          school_things / total_expenses))
print('其他方面支出：{0:.2f}元，占比：{1:.2%}'.format(other_expendses, 
                                          other_expendses / total_expenses))

# %% [markdown]
# ## 【小结】
# 在本章中，利用财经案例对 Python 中的基本操作进行了讲解。 首先， 介绍如何利用变量收集数据，接着讲解了如何利用表达式处理数据，随后讨论了财经领域非常 常见的两种数字类型：整型和浮点型，然后对于常用的字符串类型进行了表述，此后 介绍了后续程序设计中经常用到的布尔类型、逻辑运算与关系运算，此外还讨论了财 经领域常用的 Python 内置函数，最后讲解了导入模块的方法。

# %% [markdown]
# ## <font color=#A93226><b>【在线作业】</b></font>
# <br>
#
# <font size=3 face="楷体-简">
#
# 学习完本章后，请完成在线作业：<a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/exercise/75642685" style="color:#C0392B; text-decoration:none; font-size: 12pt;">《进入第2章作业》</a>
# </font>

# %% [markdown]
# <div style="
#     background-color: #000000;
#     border: 1px solid #262626;
#     border-radius: 12px;
#     padding: 30px;
#     margin: 20px 0;
#     font-family: -apple-system, 'SF Pro Display', 'Helvetica Neue', sans-serif;
#     box-shadow: 0 10px 30px rgba(0,0,0,0.5);
# ">
#     <div style="display: flex; align-items: baseline; gap: 12px; margin-bottom: 8px;">
#         <h2 style="color: #ffffff; font-size: 28px; font-weight: 600; margin: 0; letter-spacing: -0.5px;">
#             Vibe Coding
#         </h2>
#     </div>
#     <p style="color: #737373; font-size: 14px; margin: 0 0 30px 0; letter-spacing: 0.5px;">
#         NATURAL LANGUAGE DRIVEN · LOGIC ORCHESTRATION
#     </p>
#     <div style="
#         background: #0a0a0a;
#         border: 1px solid #262626;
#         border-radius: 8px;
#         padding: 24px;
#         margin-bottom: 25px;
#     ">
#         <div style="font-size: 10px; color: #0ea5e9; font-weight: 700; text-transform: uppercase; margin-bottom: 12px; letter-spacing: 1.5px;">
#             Input Intent / 意图
#         </div>
#         <p style="
#             color: #d4d4d4;
#             font-size: 19px;
#             line-height: 1.6;
#             margin: 0;
#             font-weight: 400;
#             user-select: all;
#         ">
#             我正在跟我的猫玩捉迷藏。假设我在 (0,0)，猫在 (3,4)，请调用 math 库帮我算算我要走多远才能抓到它？请用 Python 实现。
#         </p>
#     </div>
#     <div style="
#         display: flex;
#         align-items: center;
#         gap: 15px;
#         border-top: 1px solid #171717;
#         padding-top: 20px;
#     ">
#         <span style="
#             background: rgba(14, 165, 233, 0.1);
#             color: #0ea5e9;
#             font-size: 11px;
#             font-weight: 700;
#             padding: 4px 10px;
#             border-radius: 4px;
#             text-transform: uppercase;
#         ">知识点</span>
#         <span style="color: #a3a3a3; font-size: 14px; font-weight: 400;">
#             模块导入 (import math) · 几何计算
#         </span>
#     </div>
# </div>
