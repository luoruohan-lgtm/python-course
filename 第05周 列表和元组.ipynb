# %% [markdown]
# <table border="0" width="100%"><tr><td width=80 bgcolor="white"><p align="left"><img src="./Images/book.png" align="left" height="20"></p></td><td align="center" bgcolor="white"><font size="7">第3章 列表和元组</font></td></tr></table>
#
# <hr style="border:none;border-top:1px dotted red;">

# %% [markdown]
# # <font color=#A93226>【线上学习内容】</font>

# %% [markdown]
# ## 3.2　通用序列类型操作
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642692" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# ## 3.3　最灵活的序列类型：列表
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642693" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# ## 学习目标
# - 掌握序列类型的基本概念
# - 熟练序列类型的通用操作
# - 掌握列表类型的基本概念
# - 熟练列表类型的基本操作
# - 掌握元组类型的基本概念
# - 熟悉元组类型的基本操作
# - 理解列表与元组的异同点
# - 能灵活运用列表和元组解决实际问题
#
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642691" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# ## 引导案例
# <font size=3 face="楷体-简">在利用整数、浮点数、字符串、变量和表达式等 Python 基础知识编写程序展示出自己日常生活支出、学习用品支出和其他方面支出的占比情况后，小明想进一步改进程序。小明想记录每个月学习用品中支出最多的三项明细，由于每个月支出的变化，这三项学习用 品支出的名称和金额都会变化。最后，输入其中一项的名称后，打印出该项的金额和占比。</font>
# ### 案例分析
# 通过以上描述可知，小明需要记录的是会变化的三项学习用品支出情况，记录的明细情况种类数量也可能变化，分别利用变量记录每一项明细的名称和金额已经不能满足这个需求。
#
# 因此，需要用到新的数据类型，以在一个变量上存储多个项目的名称及金额。在学习本章后，请你编写程序帮助小明对学习用品支出明细进行记录和分析。

# %% [markdown]
# 在财经领域，通常需要处理的不是单个数据，而是一组相关数据。利用简单数据类型来存储和处理这些数据，无法体现数据之间的关系，并且操作变得复杂。
# Python中提供了多种组合数据类型，用来存储一组数据，包括：字符串、列表、元组、字典以及集合。
#
# 如果把布尔型、整形、浮点型这些数据类型看作组成Python的原子，那么这章要提到的数据结构就像分子一样。
#
# 下图中展示了Python中常用数据类型：
#
# <img src='./Images/5_1.png' width=600  style='display: block; margin: 0 auto;'>

# %% [markdown]
# ## 3.1　序列类型概述
# 在使用程序处理数据时，不仅需要对单个数据进行处理，计算机需要对一组数据进行批量处理。一些例子包括：
# * 统计一组问卷调查结果；
# * 给定一组工资基本信息，计算应纳税个人所得额；
# * 给定一组GDP，计算每年的增长率。
#
# 序列类型是组合数据类型的一类，能够将多个同类型或不同类型的数据组织起来，通过单一的表示使数据操作更有序更容易。
#
# 序列类型是一个元素向量，元素之间存在***先后关系***，通过序号访问，元素之间***不排他***。
#
# Python中的主要序列类型：
# - 字符串（``str``）：由按照一定顺序组合在一起的字符来构成的，例如：“金融科技”和“科技金融”就是两个不同的字符串；
# - 列表（``list``）：包含0个或多个不同类型元素的可变序列类型，用方括号将元素包含在一起，例如：
# ```python
# ['10933','李斯',40,[12000.00,400.00]]
# ```
# - 元组（``tuple``）：包含0个或多个不同类型元素的不可变序列类型，用圆括号将元素包含在一起，例如：
# ```python
# (('600000','浦发银行',11.48),('600036','招商银行',36.81))
# ```

# %% [markdown]
# ## 3.2　通用序列类型操作
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642692" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# 所有序列类型都可以进行一些特定的操作，包括索引、分片、连接、重复、成员资格检查、计算元素出现次数等。

# %% [markdown]
# ### 3.2.1　索引
#
# 序列类型是一个元素向量，元素之间存在先后关系，所有元素都有序号（有时也称为偏移量或索引）:
#
# <img src='./Images/5_2.png' width=400  style='display: block; margin: 0 auto;'><br>
#
# 序列中的元素可以通过序号进行访问:

# %%
empInfo = ['10933','李斯',40,[12000.00,400.00]]
empInfo[0]

# %% [markdown]
# 通过序号获取序列中特定位置的元素，就是索引。可以使用负数进行索引:

# %%
empInfo[-4]

# %% [markdown]
# 还可以混合使用:

# %%
empInfo[3][-1]

# %% [markdown]
# 在使用索引时，注意序号不能超过允许的范围:

# %%
empInfo = ['10933','李斯',40,[12000.00,400.00]]
empInfo[5]

# %% [markdown]
# <font color=#A93226><b>【例 3-1】</b></font> <font size=3 face="楷体-简">根据用户输入的序号，打印出对应的股票信息。</font>
#
# 程序代码如下所示：

# %%
stock_list = [['600000','浦发银行',11.52,11.54,11.61,11.40],
             ['600036','招商银行',37.27,36.84,37.44,36.52],
             ['600048','保利地产',16.87,16.61,16.93,16.45],
             ['000001','平安银行',14.73,14.49,14.68,14.40],
             ['000063','中兴通讯',41.24,40.98,41.59,40.67],
             ['300142','沃森生物',60.40,64.65,65.59,59.55]]

stock_index_str = input('请输入股票的序号：')

stock_index_number = int(stock_index_str)

stock_info = stock_list[stock_index_number - 1]

print('代码：{} 名称：{}'.format(stock_info[0], stock_info[1]))
print('开盘价：{:.2f}元 收盘价：{:.2f}'.format(stock_info[2], stock_info[3]))

print('最高价：{:.2f}元 最低价：{:.2f}'.format(stock_info[-2], stock_info[-1]))

# %% [markdown]
# ### 3.2.2 分片
# 在使用序列类型数据的过程中，常常会遇到需要获取其中一部分数据的情况。这时，可以使用分片，它是索引的一种扩展方式，返回的是序列类型数据中的一个片段，而不是一个单独的元素。

# %% [markdown]
# #### 1. 分片操作
# 如果把序号放在每个元素前，分片操作可以形象的用下图来理解：
#
# <img src='./Images/5_3.png' width=500  style='display: block; margin: 0 auto;'><br>
#
# 从上图可以看出，分片所得到的内容包含了冒号左边序号指向的字符“f”，但是没有包括冒号右边序号指向的字符“是”。

# %% [markdown]
# 对于分片，有以下一些需要注意的地方：
# - 包含左边界，不包含右边界。
# - s[:] 获得包含所有字符的新字符串，缺省的左边界为 0，右边界为序列长度。
# - s[0:7] 获得新字符串“fintech”，即序号为 0 直到序号为 7 之前的所有字符。
# - s[8:] 获得新字符串“金融科技。”，即从序号 8 到最后的所有字符。
# - s[:3] 获得新字符串“fin”，即从开头直到不包括序号为 3 之间的所有字符。
# - s[:-1] 获得新字符串“fintech 是金融科技”，即从开头直到不包括最后一个字符之间 的所有字符。

# %% [markdown]
# #### 2. 步长
# 在分片时，除了可以指定左边界和右边界的序号外（或者不指定而使用缺省值），还可以增加第三个值，即步长：
# ```python
# s[开始:结束:步长]
# ```

# %%
s = 'fintech是金融科技。'
s[1:7:2]

# %% [markdown]
# 步长也可以是负数，即以相反的顺序来获取元素:

# %%
s[::-1]

# %%
s[-2:7:-2]

# %% [markdown]
# <div style="background-color: #e6fffa; border-left: 5px solid #319795; padding: 20px; border-radius: 8px; font-family: sans-serif; margin: 20px 0;">
#     <h2 style="color: #2c7a7b; margin-top: 0;">✂️ 序列分片 (Slicing)：大模型 (LLM) 的“信息喂食器”</h2>
#     <p style="font-size: 16px; color: #333; line-height: 1.6;">你可能会觉得分片 <code>list[start:end]</code> 只是个截取数据的语法。但在 AI 时代，它是你处理海量金融文本、克服大模型局限性的核心基本功。</p>
#     <table style="width: 100%; border-collapse: separate; border-spacing: 10px; border: none; background: none;">
#         <tr style="background: none; border: none;">
#             <td style="width: 50%; background: white; padding: 15px; border-radius: 10px; box-shadow: 0 2px 5px rgba(0,0,0,0.05); vertical-align: top; border: none; border-top: 3px solid #718096;">
#                 <h4 style="color: #4a5568; margin-top: 0;">大模型的“记忆瓶颈”</h4>
#                 <p style="font-size: 14px; color: #666; margin-bottom: 0;">像 ChatGPT 或DeepSeek这样的大模型，每次能阅读的字数是有限的（称为<b>上下文窗口</b>）。如果你把包含 10 万条客户交易记录的列表直接发给它，它会报错：“超出长度限制（Token Limit Exceeded）”。</p>
#             </td>
#             <td style="width: 50%; background: white; padding: 15px; border-radius: 10px; box-shadow: 0 2px 5px rgba(0,0,0,0.05); vertical-align: top; border: none; border-top: 3px solid #38b2ac;">
#                 <h4 style="color: #2c7a7b; margin-top: 0;">Chunking（数据切块）</h4>
#                 <p style="font-size: 14px; color: #666; margin-bottom: 0;">专业的 AI 开发者会使用 Python 的<b>分片技术</b>，将长列表切割成小块。<br>例如：<code>batch = trade_list[0:100]</code>。每次只提取 100 条数据喂给大模型进行风险评估，处理完再切下一批。这在 AI 术语中叫做 <b>Chunking</b>。</p>
#             </td>
#         </tr>
#     </table>
#     <div style="background: #b2f5ea; border-radius: 5px; padding: 15px; margin: 15px 0; color: #285e61; font-style: italic;">
#         <strong>💡 财经 AI 实战启示录</strong><br>
#         在未来的智能研报系统中，如果你需要 AI 总结过去 100 天的股市行情，AI 并不是一口气吃成胖子。它背后一定运行着一行 Python 分片代码，像切香肠一样，一段一段地处理数据。掌握分片，你就掌握了掌控 AI 信息流的开关。
#     </div>
# </div>

# %% [markdown]
# ### 3.2.3 连接和复制
# **``+``** 操作符可以连接两个类型相同的序列，得到一个新的该类型序列，就像它将两个字符串合并成一个新字符串一样：

# %%
stock_name = ['600000','浦发银行']
stock_price = [11.52,11.54,11.61,11.40]
stock_info = stock_name + stock_price
print(stock_info)

# %% [markdown]
# **``*``** 操作符也可以用于其他的序列类型，序列类型的值和一个整数n相乘，得到将该序列类型值重复n次的新的对象：

# %%
['600000', '浦发银行'] * 3

# %%
('600036','招商银行') * 2

# %% [markdown]
# ### 3.2.4 使用in和not in判断
# 通过运算符in可以判断某个元素是否在序列中，如果元素在序列中，in表达式返回True，否则返回False。运算符not in则正好相反：

# %%
email_subject = '<广告>休息一下，看看有没有感兴趣的产品'
'<广告>' in email_subject

# %%
'<广告>' not in email_subject

# %% [markdown]
# ### 3.2.5 使用count元素出现次数
# 当需要计算某个元素在序列中出现的次数时，使用序列的count方法可以很轻松的完成这个任务：

# %%
stock_down_list = ['600000','600036','000001','600036','600000','300142','600036']
stock_down_list.count('600036')

# %% [markdown]
# ### <a href="https://doubao.com/bot/FWheXcyv" style="color:green;">问问大模型</a>
# ---
# <font style="color:gray;">复制下面的提示词，点击"问问大模型"，将提示词粘贴到你所使用的大模型</font>
#
#
#
# <font style="color:brown;font-weight: bold;">提示词:</font><br>
# 我是Python初学者，请你解释一下下面的代码结果为什么是2，不是3？
# ```python
# stock_down_list = ['600000', ['600036'],'000001','600036','600000','300142','600036']
# stock_down_list.count('600036')
# ```
#
# ---

# %% [markdown]
# <font style="color:red;font-weight: bold;">学会从大模型的思考过程中学习！！！</font>

# %% [markdown]
# <img src='./Images/5_4.png' style="height: 800px; border: 0.1px solid black;">

# %% [markdown]
# ### 3.2.6 序列类型通用操作符和函数
# 序列类型有12个通用的操作符和函数:<br>
# <font color="gray" size=1>注：下表中s和t为序列类型，x为元素，i和j为整数
#
# |操作符|描述|
# |:----:|:----------|
# |**x in s**|如果x是s的元素，返回True，否则返回False|
# |**x not in s**|如果x不是s的元素，返回True，否则返回False|
# |**s + t**|连接s和t||
# |**s \* n 或 n \* s**|将序列s复制n次|
# |**s[i]**|索引，返回序列的第i个元素|
# |**s[i: j]**|分片，返回包含序列s第i到j个元素的子序列（不包含第j个元素）|
# |**s[i: j: k]**|步骤分片，返回包含序列s第i到j个元素以j为步数的子序列|
# |**len(s)**|序列s的元素个数（长度）|
# |**min(s)**|序列s中的最小元素|
# |**max(s)**|序列s中的最大元素|
# |**s.index(x[, i[, j]])**|序列s中从i开始到j位置中第一次出现元素x的位置|
# |**s.count(x)**|序列s中出现x的总次数|

# %% [markdown]
# ## 3.3　最灵活的序列类型：列表
# <a href="https://www.xuetangx.com/learn/space/swufe08091006588/swufe08091006588/29598038/video/75642693" style="color:#BDC3C7; text-decoration:none; font-size: 10pt;">《观看在线视频》</a>

# %% [markdown]
# <font color=red>列表是一个值</font>，它包含多个值构成的序列。术语“列表值”指的是列表本身（它作为一个值，可以保存在变量中，或传递给函数，像所有其他值一样），而不是指列表值之内的那些值。
#
# 列表值看起来像这样：['西南财经大学', '电子科技大学', '四川大学', '西南交通大学']。
#
# 就像字符串值用引号来标记字符串的起止一样，***列表用左方括号开始，右方括号结束，即[ ]***。列表中的值也称为“表项”。表项用***逗号分隔***（就是说，它们是“逗号分隔的”）。
#
# 列表的长度和内容都是**可变的**，可自由对列表中数据项进行增加、删除或替换。列表没有长度限制，元素类型可以不同，使用非常灵活。
#
# 由于列表属于序列类型，所以列表也支持成员关系操作符（in）、长度计算函数（len()）、分片（[]）。
#
# 列表可以同时使用正向递增序号和反向递减序号，可以采用标准的比较操作符（ **<、<=、==、!=、>=、>** ）进行比较，列表的比较实际上是单个数据项的逐个比较。
#
# **列表的操作**
#
# <font color="gray" size=1>注：下表中s和t为列表，x为元素，i和j为整数
#
# |函数或方法|描述|
# |:---:|:----------|
# |s[i] = x|	替换列表s第i数据项为x|
# |s[i: j] = t|	用列表t替换列表s中第i到j项数据（不含第j项，下同）|
# |s[i: j: k] = t|用列表t替换列表s中第i到j以k为步的数据|
# |del s[i: j]|删除列表s第i到j项数据，等价于s[i: j]=[]|
# |del s[i: j: k]|删除列表s第i到j以k为步的数据|
# |s += t或s.extend(t)|将列表t元素增加到列表s中|
# |s \*= n|更新列表s，其元素重复n次|
# |s.append(x)|在列表s最后增加一个元素x|
# |s.clear()|删除s中所有元素|
# |s.copy()|生成一个新列表，复制s中所有元素|
# |s.insert(i, x)|在列表s第i位置增加元素x|
# |s.pop(i)|将列表s中第i项元素取出并删除该元素||
# |s.remove(x)|将列表s中出现的第一个元素x删除|
# |s.reverse()|列表s中元素反转|
# |s.index(x)|找出某个值第一个匹配项的索引位置|

# %% [markdown]
# ### 3.3.1　创建列表
# 在Python中，通常用``list``函数或方括号``[ ]``来创建列表：
# #### 1. list 函数

# %%
list('招商银行')

# %% [markdown]
# 参数可以是字符串、元组、字典或者集合。但不能是整数、浮点数或者布尔值：

# %%
list(10.8)

# %% [markdown]
# 这里出现TypeError的异常，表示float对象是不能被迭代的。也就是说，在``list``函数只能将可迭代对象转换为列表。

# %% [markdown]
# #### 2. 方括号
# 使用方括号``[]``创建列表时，需要在列表中列出所有元素：

# %%
['招商银行']

# %%
['招','商','银','行']

# %% [markdown]
# #### 3. 空列表
# 可以使用``list``函数和方括号``[ ]``创建空列表：

# %%
list()

# %%
[]

# %% [markdown]
# #### 4.嵌套列表
#
# 列表也可以包含其他列表值。这些列表的列表中的值，可以通过多重下标来访问，像这样：

# %%
# 编号,姓名,基本工资,奖金,住房补助,五险一金,其他扣款,专项附加扣除
incomeList = [
    ['10932','张珊',15000.00 ,4000.00 ,2300.00 ,980.00 ,300.00 ,1000.00],
    ['10933','李思',12000.00 ,5000.00 ,2600.00 ,890.00 ,400.00 ,2000.00],
    ['10934','王武',10100.00 ,2000.00 ,2500.00 ,860.00 ,500.00 ,1500.00],
    ['10935','赵柳',10050.00 ,1000.00 ,2700.00 ,1080.00 ,300.00 ,2000.00],
    ['10936','钱棋',10200.00 ,2000.00 ,2400.00 ,1000.00 ,600.00 ,1000.00],
    ['10941','张明',13600.00 ,4000.00 ,2100.00 ,680.00 ,300.00 ,1000.00],
    ['10942','赵敏',13200.00 ,2500.00 ,2300.00 ,670.00 ,400.00 ,3000.00],
    ['10945','王红',13600.00 ,2600.00 ,2030.00 ,560.00 ,400.00 ,2000.00],
    ['10946','李萧',12500.00 ,2800.00 ,2400.00 ,420.00 ,500.00 ,1500.00],
    ['10947','孙科',12000.00 ,3500.00 ,2030.00 ,880.00 ,300.00 ,1000.00],
    ['10948','刘利',14200.00 ,2500.00 ,2020.00 ,900.00 ,400.00 ,2000.00]
]

# %%
incomeList

# %%
incomeList[1][1]

# %% [markdown]
# ### 3.3.2　列表基本操作
# 由于***列表是可变的***， 因此列表有些专用的方法： 元素修改、元素删除和分片赋值。这些方法都是在列表原位置进行修改，也就是改变了列 表本身的值，而不是创建新的列表。

# %% [markdown]
# #### 1. 元素修改
# 在列表创建后，可以通过元素赋值的方式修改列表中的元素。一般情况下，赋值语句左边是一个变量名，就像price = 4.00。但是，也可以使用列表的下标来改变下标处的值。

# %%
stock_info = ['600000', '浦发银行', 11.52, 11.54, 11.61, 11.4]
stock_info[4] = 12.00
stock_info

# %% [markdown]
# #### 2. 元素删除
# 可以使用 Python 的内置函数 del 删除列表中的一个或多个元素：

# %%
stock_info = ['600000', '浦发银行', 11.52, 11.54, 11.61, 11.4]
del stock_info[1]
stock_info

# %%
del stock_info[1:3]
stock_info

# %% [markdown]
# #### 3. 分片赋值
# Python 支持列表的分片赋值， 这使得仅仅用一步操作就可以将列表中的整个片段替换掉。

# %%
stock_info = ['600000', '浦发银行', 0, 0, 0, 0]
stock_info[2:] = [11.52, 11.54, 11.61, 11.4]
stock_info

# %% [markdown]
# 当使用一个列表改变另一个列表值时，Python不要求两个列表长度一样，但遵循 **“多增少减”** 的原则。利用这个特性，可以通过分片赋值实现列表元素的删除和插入：

# %%
stock_info = ['600000', '浦发银行', 11.52, 11.54, 11.61, 11.4]
stock_info[2:5] = []
stock_info

# %% [markdown]
# #### 4.多重赋值技巧
# 多重赋值技巧是一种快捷方式，让你在一行代码中，用列表中的值为多个变量赋值。

# %%
incomeList = [['10932', '张珊', 15000.0, 4000.0, 2300.0, 980.0, 300.0, 1000.0],
              ['10933', '李思', 12000.0, 5000.0, 2600.0, 890.0, 400.0, 2000.0],
              ['10934', '王武', 10100.0, 2000.0, 2500.0, 860.0, 500.0, 1500.0],
              ['10935', '赵柳', 10050.0, 1000.0, 2700.0, 1080.0, 300.0, 2000.0],
              ['10936', '钱棋', 10200.0, 2000.0, 2400.0, 1000.0, 600.0, 1000.0],
              ['10941', '张明', 13600.0, 4000.0, 2100.0, 680.0, 300.0, 1000.0],
              ['10942', '赵敏', 13200.0, 2500.0, 2300.0, 670.0, 400.0, 3000.0],
              ['10945', '王红', 13600.0, 2600.0, 2030.0, 560.0, 400.0, 2000.0],
              ['10946', '李萧', 12500.0, 2800.0, 2400.0, 420.0, 500.0, 1500.0],
              ['10947', '孙科', 12000.0, 3500.0, 2030.0, 880.0, 300.0, 1000.0],
              ['10948', '刘利', 14200.0, 2500.0, 2020.0, 900.0, 400.0, 2000.0]]
incomeList[0][:3]

# %%
employeeBasicInfo = incomeList[0][:3]
employeeBasicInfo

# %%
type(employeeBasicInfo)

# %%
employeeNo, name, salary = employeeBasicInfo

# %%
print('编号为{}的员工{}基本工资为：{:.2f}'.format(employeeNo, name, salary))

# %% [markdown]
# ### 3.3.3　列表常用方法

# %% [markdown]
# #### 1. extend 方法
# 使用 ``extend`` 方法， 可以一次在列表的末端插入多个元素。 这是一个对列表进行原地修改的方法。

# %%
stock_info = ['600000', '浦发银行']
stock_price = [11.52, 11.54, 11.61, 11.4]
stock_info.extend(stock_price)
stock_info

# %% [markdown]
# 也可以使用+=：

# %%
stock_info = ['600000', '浦发银行']
stock_price = [11.52, 11.54, 11.61, 11.4]
stock_info += stock_price
stock_info

# %% [markdown]
# #### 2. append 方法
# ``append`` 方法与 ``extend`` 类似，也可以在列表末端添加元素。 不同的是，使用 ``append`` 方 法会直接把传入的参数（可以是任何类型）添加到尾部而不是遍历它。

# %%
stock_info = ['600000', '浦发银行']
stock_price = [11.52, 11.54, 11.61, 11.4]
stock_info.append(stock_price)
stock_info

# %% [markdown]
# ### <a href="https://doubao.com/bot/FWheXcyv" style="color:green;">问问大模型</a>
# ---
# <font style="color:gray;">复制下面的提示词，点击"问问大模型"，将提示词粘贴到你所使用的大模型</font>
#
#
#
# <font style="color:brown;font-weight: bold;">提示词:</font><br>
# 我是Python初学者，请你举例说明列表append方法和extend方法的区别。
#
# ---

# %% [markdown]
# #### 3. pop 方法
# 使用 ``pop`` 方法可以移除并返回指定列表中某个位置的元素。``pop`` 方法通过唯一的参数 指定需要移除并返回元素的位置，如果不指定，默认移除并返回最后一个元素。
#
# 在实际应用中， 常常会遇到先进先出（first-in-first-out，FIFO）的队列操作。
#
# <img src='./Images/5_5.png' width=500  style='display: block; margin: 0 auto;'><br>

# %% [markdown]
# <font color=#A93226><b>【例 3-2】</b></font> <font size=3 face="楷体-简">编写程序，要求用户输入股票名称，按照先进先出的规则打印出股票名称。</font>
#
# 程序代码如下所示：

# %%
stock_list = []
stock_name = input('请输入股票名称：')
stock_list.append(stock_name)
stock_name = input('请输入股票名称：')
stock_list.append(stock_name)
stock_name = input('请输入股票名称：')
stock_list.append(stock_name)
stock_name = input('请输入股票名称：')
stock_list.append(stock_name)
print('-' * 20)
print(stock_list.pop(0))
print(stock_list.pop(0))
print(stock_list.pop(0))
print(stock_list.pop(0))

# %% [markdown]
# #### 4. copy 方法

# %% [markdown]
# ### <a href="https://doubao.com/bot/FWheXcyv" style="color:green;">问问大模型</a>
# ---
# <font style="color:gray;">复制下面的提示词，点击"问问大模型"，将提示词粘贴到你所使用的大模型</font>
#
#
#
# <font style="color:brown;font-weight: bold;">提示词:</font><br>
# 我是Python初学者，请你解释一下为什么下面代码中的s值变了？
#
# ```python
# s = [1,2,3,4]
# t = s
# t[1] = 100
# print(s)
# ```
#
# ---

# %% [markdown]
# 再来看一个实例。

# %% [markdown]
# <font color=#A93226><b>【例 3-3】</b></font> <font size=3 face="楷体-简">使用列表 stock_info 来存储股票基本信息，列表 stock_day1、stock_day2 等用 于存储股票的基本信息和每天的交易信息（开盘价、收盘价、最高价、最低价）。</font>
#
# 程序代码如下所示：

# %%
stock_info = ['600000','浦发银行']
stock_day1 = stock_info  
stock_day1.extend([11.52,11.54,11.61,11.40]) # 第1天的交易信息
stock_day2 = stock_info
stock_day2.extend([11.54,11.98,12.11,11.20]) # 第2天的交易信息
print(stock_day1)
print(stock_day2)

# %% [markdown]
# 从最终的结果发现， 这段代码并没有实现我们所希望的功能， 最终的 stock_day1 和 stock_day2 两个列表包含了两天的交易数据。那为什么会出现这样的错误呢？这实际上与 Python 的内在实现机制有关。
#
# <img src='./Images/5_6.png' width=500  style='display: block; margin: 0 auto;'><br>

# %% [markdown]
# 那如果我们希望赋值后的 stock_day1 和 stock_day2 相互独立怎么办呢？这时就要使用到列表的 ``copy`` 方法， ``copy`` 方法会生成一个新的列表，复制调用者的所有元素：

# %%
stock_info = ['600000','浦发银行']
stock_day1 = stock_info.copy() # 利用copy复制后再赋值 
stock_day1.extend([11.52,11.54,11.61,11.40]) # 第1天的交易信息
stock_day2 = stock_info.copy() # 利用copy复制后再赋值
stock_day2.extend([11.54,11.98,12.11,11.20]) # 第2天的交易信息
print(stock_day1)
print(stock_day2)

# %% [markdown]
# 以上代码的赋值过程如下图所示：
#
# <img src='./Images/5_7.png' width=500  style='display: block; margin: 0 auto;'><br>

# %% [markdown]
# ### 5. sort 方法
# 数值的列表或字符串的列表，能用``sort()``方法排序。``sort()``方法**当场**对列表排序：

# %%
stock_list = ['600000','600036','000001','300142','600048']
stock_list.sort()  # 默认升序排列
stock_list

# %%
help(stock_list.sort)

# %% [markdown]
# 也可以指定**reverse**关键字参数为True，让``sort()``按逆序排序。

# %%
stock_list.sort(reverse=True)
stock_list

# %% [markdown]
# 不能对既有数字又有字符串值的列表排序，因为Python 不知道如何比较它们。

# %%
moreList = stock_list + list(range(5))
moreList

# %%
moreList.sort()

# %% [markdown]
# ``sort()``方法对字符串排序时，使用“ASCII 字符顺序”，而不是实际的字典顺序。这意味着大写字母排在小写字母之前。因此在排序时，小写的a 在大写的
# Z 之后:

# %%
someWords = ['Alice', 'ants', 'Bob', 'badgers', 'Carol', 'cats']
someWords

# %%
someWords.sort()

# %%
someWords

# %% [markdown]
# ***扩展***
#
# ``sort()``方法有一个key的关键字参数，可以指定排序方法，例如：

# %%
someWords = ['Alice', 'ants', 'Bob', 'badgers', 'Carol', 'cats']
someWords

# %%
someWords.sort(key=len)
someWords #按照每一项的长度进行排序

# %% [markdown]
# <font color=#A93226><b>【课堂练习】</b></font>  <font size=3 face="楷体-简">
#
# 有5个人竞拍，按照规则，出价最高者获得拍卖品。编写程序，由5个人分别输入他们的名字和竞拍价，最后打印出获得拍卖品者的名字和价格。</font>
#
# <font size=2 color="gray">
# 注：名字和竞拍价之间用逗号隔开。</font>

# %%
## 提示如下：
## Step0: 定一个列表储存所有信息
results = []

## Step1: 由5个人分别输入他们的名字和竞拍价
## 注：名字和竞拍价之间用逗号隔开。

## Step2: 用户输入的信息添加到results最后

## Step3: 将竞拍价转化为浮点数

## Step4: 按照竞拍价进行排序 （从高到低）

## Step5: 打印输出竞拍价最高的用户名字和竞拍价

# %% [markdown]
# <font color=#145A32><b>【体验Pythonic】</b></font>  <font size=3 face="楷体-简">
#
# <font size=3 color="gray">学完控制结构和函数后，这个问题更加容易，先体验一下：</font>

# %%
result = []
for i in range(5):
    result.append(input("请输入您的名字和竞拍价：").split(","))
result.sort(key=lambda item: float(item[1]), reverse=True)
print(f"获得拍卖品的是：{result[0][0]}，出价为：{float(result[0][1]):.2f}元")

# %% [markdown]
# ### 6.其他常用方法
# 通过 ``insert()`` 方法可以将元素插入列表指定的位置，``insert()`` 需要两个参数， 第 1 个参数指定需要插入的位置， 第 2 个参数指定需要插入的元素：

# %%
stock_name = ['浦发银行','招商银行','平安银行']
stock_name.insert(2,'保利地产')
stock_name

# %% [markdown]
# 通过 ``clear()`` 方法可以清空列表中的所有元素：

# %%
stock_name = ['浦发银行','招商银行','平安银行']
stock_name.clear()
stock_name

# %% [markdown]
# 通过 ``remove()`` 方法可以移除列表中的某个元素， 当元素在列表中重复出现时， 仅移除 第 1 次出现的值：

# %%
stock_name = ['浦发银行','招商银行','平安银行','招商银行']
stock_name.remove('招商银行')
stock_name

# %% [markdown]
# 通过 ``reverse()`` 方法可以将列表中的元素反向存储：

# %%
stock_name = ['浦发银行','招商银行','平安银行']
stock_name.reverse()
stock_name

# %% [markdown]
# 通过 ``index()`` 方法找出列表某个值第一个匹配项的索引位置：

# %%
stock_name = ['浦发银行','招商银行','平安银行']
stock_name.index('招商银行')

# %% [markdown]
# <div style="background-color: #f5f3ff; border-left: 5px solid #7c3aed; padding: 20px; border-radius: 8px; font-family: sans-serif; margin: 20px 0;">
#     <h2 style="color: #5b21b6; margin-top: 0;">🧠 列表的动态增删：AI 智能体 (Agent) 的“任务流水线”</h2>
#     <p style="font-size: 16px; color: #333; line-height: 1.6;">学习了 <code>append()</code> 和 <code>pop()</code>，你可能觉得它们只是用来修改学员名单或购物车商品的。其实，<b>现代最前沿的自主智能体（AutoGPT 等）的核心运作机制，就是一个不断增删的 Python 列表！</b></p>
#     <div style="background: white; padding: 15px; border-radius: 10px; box-shadow: 0 2px 5px rgba(0,0,0,0.05); margin-top: 15px;">
#         <h4 style="color: #2d3748; margin-top: 0; border-bottom: 1px dashed #ccc; padding-bottom: 10px;">🤖 Agent 是如何思考和行动的？</h4>
#         <p style="font-size: 14px; color: #555;">当你给 AI 下达一个复杂指令：“帮我收集今天新能源板块的财报，并写一份摘要。” AI 不会魔法，它会在后台创建一个<b>任务列表（Task Queue）</b>：</p>
#         <div style="background: #2d3748; color: #e2e8f0; padding: 15px; border-radius: 5px; font-family: monospace; font-size: 14px; line-height: 1.6;">
#             <span style="color: #a0aec0;"># 1. AI 拆解任务并加入列表 (append)</span><br>
#             <span style="color: #fbd38d;">task_list</span> = []<br>
#             <span style="color: #fbd38d;">task_list</span>.append(<span style="color: #9ae6b4;">"1. 搜索新能源公司名单"</span>)<br>
#             <span style="color: #fbd38d;">task_list</span>.append(<span style="color: #9ae6b4;">"2. 下载最新财报"</span>)<br>
#             <span style="color: #fbd38d;">task_list</span>.append(<span style="color: #9ae6b4;">"3. 生成财务摘要"</span>)<br><br>
#             <span style="color: #a0aec0;"># 2. AI 按照顺序执行，做完一个就删掉一个 (pop)</span><br>
#             current_task = <span style="color: #fbd38d;">task_list</span>.pop(0) <span style="color: #a0aec0;"># 取出第一项任务去执行...</span><br>
#             <span style="color: #a0aec0;"># 如果执行过程中发现新问题，AI 还会随时 append 新任务！</span>
#         </div>
#     </div>
#     <h3 style="color: #2c3e50; margin-top: 20px;">💡 Vibe Coding 启示录</h3>
#     <p style="font-size: 15px; color: #444; line-height: 1.6;">未来在企业中，你可能不需要亲自写这些复杂的爬虫代码。但如果你想要指挥一个 AI Agent 帮你做事，你必须具备“列表思维”。你需要清晰地知道，你给 AI 的任务能否被拆解成一个个可以用 <code>append()</code> 添加、用 <code>pop()</code> 执行的步骤。<b>这正是计算思维在 AI 时代的升华。</b></p>
# </div>

# %% [markdown]
# ## 3.3.4 <font color=#A93226>案例：</font>复利计算
#
# <font size=3>等复利现值是指在计算复利的情况下，要达到未来某一特定的资金金额，现在必须投入的本金。</font><br><br>
# <font size=3 face="楷体-简">    编写程序实现复利现值计算， 假定平均的年回报率是 3%， 存入年限为 5 年， 当用户输入复利终值后，按照复利终值计算现在需投入的本金是多少？每年的本息金额是多少？
# </font>

# %%
final_amt = float(input('请输入复利终值：'))
amt_list = [final_amt]
rate = 0.03
pre_amt = amt_list[-1] / (1 + rate)
amt_list.append(pre_amt)
pre_amt = amt_list[-1] / (1 + rate)
amt_list.append(pre_amt)
pre_amt = amt_list[-1] / (1 + rate)
amt_list.append(pre_amt)
pre_amt = amt_list[-1] / (1 + rate)
amt_list.append(pre_amt)
pre_amt = amt_list[-1] / (1 + rate)
amt_list.append(pre_amt)
amt_list.reverse()
print('-' * 25)
print('需投入本金为： {:.2f}元'.format(amt_list[0]))
print('第1年本息余额：{:.2f}元'.format(amt_list[1]))
print('第2年本息余额：{:.2f}元'.format(amt_list[2]))
print('第3年本息余额：{:.2f}元'.format(amt_list[3]))
print('第4年本息余额：{:.2f}元'.format(amt_list[4]))
print('第5年本息余额：{:.2f}元'.format(amt_list[5]))

# %% [markdown]
# ### <a href="https://doubao.com/bot/FWheXcyv" style="color:green;">问问大模型</a>
# ---
# <font style="color:gray;">复制下面的提示词，点击"问问大模型"，将提示词粘贴到你所使用的大模型</font>
#
# <font style="color:gray;">说明：对于这类问题，不需要使用推理模型，使用对话模型效果会更好。</font>
#
#
#
# <font style="color:brown;font-weight: bold;">提示词:</font><br>
# 请给我讲一个复利有关的有趣例子。
#
# ---

# %% [markdown]
# <div style="
#     background-color: #000000;
#     border: 1px solid #262626;
#     border-radius: 12px;
#     padding: 30px;
#     margin: 20px 0;
#     font-family: -apple-system, 'SF Pro Display', 'Helvetica Neue', sans-serif;
#     box-shadow: 0 10px 30px rgba(0,0,0,0.5);
# ">
#     <div style="display: flex; align-items: baseline; gap: 12px; margin-bottom: 8px;">
#         <h2 style="color: #ffffff; font-size: 28px; font-weight: 600; margin: 0; letter-spacing: -0.5px;">
#             Vibe Coding
#         </h2>
#     </div>
#     <p style="color: #737373; font-size: 14px; margin: 0 0 30px 0; letter-spacing: 0.5px;">
#         NATURAL LANGUAGE DRIVEN · LOGIC ORCHESTRATION
#     </p>
#     <div style="
#         background: #0a0a0a;
#         border: 1px solid #262626;
#         border-radius: 8px;
#         padding: 24px;
#         margin-bottom: 25px;
#     ">
#         <div style="font-size: 10px; color: #0ea5e9; font-weight: 700; text-transform: uppercase; margin-bottom: 12px; letter-spacing: 1.5px;">
#             Input Intent / 意图
#         </div>
#         <p style="
#             color: #d4d4d4;
#             font-size: 19px;
#             line-height: 1.6;
#             margin: 0;
#             font-weight: 400;
#             user-select: all;
#         ">
#             帮我生成一个‘超级英雄名单’。然后演示一下如何通过‘分片’魔法，把这个名单里的第一名（领队）和最后两名（后勤）快速提取出来。请用 Python 实现。
#         </p>
#     </div>
#     <div style="
#         display: flex;
#         align-items: center;
#         gap: 15px;
#         border-top: 1px solid #171717;
#         padding-top: 20px;
#     ">
#         <span style="
#             background: rgba(14, 165, 233, 0.1);
#             color: #0ea5e9;
#             font-size: 11px;
#             font-weight: 700;
#             padding: 4px 10px;
#             border-radius: 4px;
#             text-transform: uppercase;
#         ">知识点</span>
#         <span style="color: #a3a3a3; font-size: 14px; font-weight: 400;">
#             列表 (List) · 切片 (Slicing) · 负数索引
#         </span>
#     </div>
# </div>
